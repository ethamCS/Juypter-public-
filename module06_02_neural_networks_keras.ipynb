# %% [markdown]
# <a href="https://colab.research.google.com/github/ethamCS/Juypter-public-/blob/main/module06_02_neural_networks_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Networs and Keras
#
# This notebook is part of  course materials for CS 345: Machine Learning Foundations and Practice at Colorado State University.
# Original versions were created by Ben Sattelberg and Asa Ben-Hur with updates by Ross Beveridge.
#
# Last Update 11/09/2021
#
#
# *The text is released under the [CC BY-SA license](https://creativecommons.org/licenses/by-sa/4.0/), and code is released under the [MIT license](https://opensource.org/licenses/MIT).*

# %% [markdown]
# # Neural Networks

# %%
# %matplotlib inline
import numpy as np
from numpy.random import default_rng

import matplotlib.pyplot as plt
import matplotlib

from IPython import display
from base64 import b64decode

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import keras

import tensorflow as tf
#tf.compat.v1.enable_eager_execution()
tf.executing_eagerly()
# Out:
# Using TensorFlow backend.
# False

# %% [markdown]
# ### Plotting functionality for later

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_XOR_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')

    delta = 0.01
    xmin=-0.1;xmax=1.1;ymin=-0.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-1, vmax=1)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
    y = np.array([1, 0, 0, 1])

    plt.style.use('default')
    ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);
#     ax2.scatter(X[:,0], X[:,1], y, c=y, alpha=1, s=20, cmap='bwr')

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %%
def plot_circles_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')
    
    r1 = 0.5
    r2 = np.sqrt(2*r1**2)
    r3 = np.sqrt(r1**2 + r2**2)

    delta = 0.01
    xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-0.001, vmax=0.001)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    plt.style.use('default')
    #ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()
    
    circle = plt.Circle((0, 0), r1, alpha=0.5, edgecolor='k')
    annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, facecolor='r', alpha=0.5, edgecolor='k')
    ax.add_artist(circle)
    ax.add_artist(annulus)

# %% [markdown]
# ## Introduction to Keras

# %% [markdown]
# Last time we introduced neural networks and built a simple architecture we could use to (sometimes) solve the XOR problem.  We saw the challenge of programming a network with increasing numbers of units and layers.
#
# Fortunately, there exist a number of packages designed for neural networks use that automatically determine the correct update rules with backpropagation.  A few of the packages that are used in CSU's CS department are [TensorFlow](https://www.tensorflow.org), [PyTorch](https://pytorch.org), and [Keras](https://keras.io).  These packages use Python despite the fact that Python is can be relatively slow compared to compiled languages.  These deep learning packages often compile their code into those faster languages or are able to take advantage of optimizations that give competitive performance.
#
# We'll use Keras with a TensorFlow backend as it is simple to use and competitive with other options.

# %% [markdown]
# The [Keras website](https://keras.io/) has good tutorials and documentation.

# %% [markdown]
# First, we will create our dataset - the same XOR problem discussed in the previous notebook.  The only difference is that we convert the input values to be 32 bit floating point values, rather than 64 bit.  This isn't strictly necessary, but most neural network packages use 32 bit floats because the added precision is not worth the memory and computational cost.

# %%
X_xor = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y_xor = np.array([1, 0, 0, 1])

X_xor = X_xor.astype('float32')

# %% [markdown]
# Now we can set up a network.  We will use a ```Sequential``` network, which is the container for a multilayer perceptron/feedforward neural network structure. Keep in mind this is exactly the general type of network introduced in the multi-layer perceptron buildt from scratch earlier.

# %%
network1 = keras.Sequential()

# %% [markdown]
# Now we can add layers to it.  The first layer we add is our hidden layer.  Having two nodes would give us a network which *can* work, but frequently doesn't, so let's create a much larger network with ten nodes in its hidden layer.  This is referred to as a ```Dense``` layer, as every input has a weight connecting it to every node in the previous layer.  We also tell Keras to use the ReLU activation function for it.
#
# Finally, we will add a layer that transforms the outputs of the hidden layer into the single output value.  By not passing an activation function in, this defaults to having no activation function.

# %%
network1.add(keras.layers.Dense(10, activation='relu'))
network1.add(keras.layers.Dense(1))

# %% [markdown]
# This sets up a network that looks like this:

# %%
# Code here just allows image to be contained within this file
bar = '...'
display.Image(b64decode(bar),width=800)

# %% [markdown]
# Given the network, we can now set up the training process.  We will use the mean squared error as the loss function and use stochastic gradient descent as the optimzer:

# %%
loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.SGD(learning_rate=0.005)

# %% [markdown]
# The command ```network.compile(...)``` constructs the network as something that can be trained or evaluated.  The ```metrics``` parameter accepts a list of values that we want to keep track of during the training process.

# %%
network1.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %% [markdown]
# With all of the set up out of the way, we are ready to train the network.  The ```batch_size``` controls how many inputs to pass through the network at a time.   With traditional gradient descent it would be every input and with traditional stochastic gradient descent it would be a single input.  The ```verbose``` parameter controls to what extent the network prints output reflecting its progress.  Notice that it keeps track of the loss used for training, and the 'accuracy' and 'mse' values that we passed as metrics of interest.  In this case the loss is MSE, so the two values are the same.

# %%
n_epochs = 512
history1 = network1.fit(X_xor, y_xor, batch_size=2, epochs=n_epochs, verbose=1)
# Out:
# WARNING:tensorflow:From /Users/ross/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/512
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5424 - accuracy: 0.5000 - mse: 0.5424
# Epoch 2/512
# 4/4 [==============================] - 0s 665us/step - loss: 0.5206 - accuracy: 0.5000 - mse: 0.5206
# Epoch 3/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.4999 - accuracy: 0.5000 - mse: 0.4999
# Epoch 4/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.4808 - accuracy: 0.5000 - mse: 0.4808
# Epoch 5/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.4633 - accuracy: 0.5000 - mse: 0.4633
# Epoch 6/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.4465 - accuracy: 0.5000 - mse: 0.4465
# Epoch 7/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.4306 - accuracy: 0.5000 - mse: 0.4306
# Epoch 8/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.4174 - accuracy: 0.5000 - mse: 0.4174
# Epoch 9/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.4017 - accuracy: 0.5000 - mse: 0.4017
# Epoch 10/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.3885 - accuracy: 0.5000 - mse: 0.3885
# Epoch 11/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.3758 - accuracy: 0.5000 - mse: 0.3758
# Epoch 12/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.3645 - accuracy: 0.5000 - mse: 0.3645
# Epoch 13/512
# 4/4 [==============================] - 0s 652us/step - loss: 0.3554 - accuracy: 0.5000 - mse: 0.3554
# Epoch 14/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.3433 - accuracy: 0.5000 - mse: 0.3433
# Epoch 15/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.3332 - accuracy: 0.5000 - mse: 0.3332
# Epoch 16/512
# 4/4 [==============================] - 0s 532us/step - loss: 0.3241 - accuracy: 0.5000 - mse: 0.3241
# Epoch 17/512
# 4/4 [==============================] - 0s 547us/step - loss: 0.3158 - accuracy: 0.5000 - mse: 0.3158
# Epoch 18/512
# 4/4 [==============================] - 0s 582us/step - loss: 0.3076 - accuracy: 0.5000 - mse: 0.3076
# Epoch 19/512
# 4/4 [==============================] - 0s 581us/step - loss: 0.2998 - accuracy: 0.5000 - mse: 0.2998
# Epoch 20/512
# 4/4 [==============================] - 0s 560us/step - loss: 0.2926 - accuracy: 0.5000 - mse: 0.2926
# Epoch 21/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.2859 - accuracy: 0.5000 - mse: 0.2859
# Epoch 22/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.2793 - accuracy: 0.5000 - mse: 0.2793
# Epoch 23/512
# 4/4 [==============================] - 0s 542us/step - loss: 0.2755 - accuracy: 0.5000 - mse: 0.2755
# Epoch 24/512
# 4/4 [==============================] - 0s 671us/step - loss: 0.2675 - accuracy: 0.5000 - mse: 0.2675
# Epoch 25/512
# 4/4 [==============================] - 0s 630us/step - loss: 0.2620 - accuracy: 0.5000 - mse: 0.2620
# Epoch 26/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.2571 - accuracy: 0.5000 - mse: 0.2571
# Epoch 27/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.2523 - accuracy: 0.5000 - mse: 0.2523
# Epoch 28/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.2474 - accuracy: 0.5000 - mse: 0.2474
# Epoch 29/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.2431 - accuracy: 0.5000 - mse: 0.2431
# Epoch 30/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.2411 - accuracy: 0.5000 - mse: 0.2411
# Epoch 31/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.2349 - accuracy: 0.5000 - mse: 0.2349
# Epoch 32/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.2313 - accuracy: 0.5000 - mse: 0.2313
# Epoch 33/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.2278 - accuracy: 0.5000 - mse: 0.2278
# Epoch 34/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.2243 - accuracy: 0.5000 - mse: 0.2243
# Epoch 35/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.2212 - accuracy: 0.5000 - mse: 0.2212
# Epoch 36/512
# 4/4 [==============================] - 0s 580us/step - loss: 0.2180 - accuracy: 0.5000 - mse: 0.2180
# Epoch 37/512
# 4/4 [==============================] - 0s 547us/step - loss: 0.2172 - accuracy: 0.5000 - mse: 0.2172
# Epoch 38/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.2144 - accuracy: 0.5000 - mse: 0.2144
# Epoch 39/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.2097 - accuracy: 0.5000 - mse: 0.2097
# Epoch 40/512
# 4/4 [==============================] - 0s 523us/step - loss: 0.2070 - accuracy: 0.5000 - mse: 0.2070
# Epoch 41/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.2045 - accuracy: 0.5000 - mse: 0.2045
# Epoch 42/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.2024 - accuracy: 0.5000 - mse: 0.2024
# Epoch 43/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.1999 - accuracy: 0.5000 - mse: 0.1999
# Epoch 44/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.1999 - accuracy: 0.5000 - mse: 0.1999
# Epoch 45/512
# 4/4 [==============================] - 0s 574us/step - loss: 0.1958 - accuracy: 0.7500 - mse: 0.1958
# Epoch 46/512
# 4/4 [==============================] - 0s 681us/step - loss: 0.1939 - accuracy: 0.7500 - mse: 0.1939
# Epoch 47/512
# 4/4 [==============================] - 0s 768us/step - loss: 0.1920 - accuracy: 0.7500 - mse: 0.1920
# Epoch 48/512
# 4/4 [==============================] - 0s 592us/step - loss: 0.1902 - accuracy: 0.7500 - mse: 0.1902
# Epoch 49/512
# 4/4 [==============================] - 0s 585us/step - loss: 0.1884 - accuracy: 0.7500 - mse: 0.1884
# Epoch 50/512
# 4/4 [==============================] - 0s 566us/step - loss: 0.1867 - accuracy: 0.7500 - mse: 0.1867
# Epoch 51/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.1872 - accuracy: 0.7500 - mse: 0.1872
# Epoch 52/512
# 4/4 [==============================] - 0s 550us/step - loss: 0.1836 - accuracy: 0.7500 - mse: 0.1836
# Epoch 53/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.1821 - accuracy: 0.7500 - mse: 0.1821
# Epoch 54/512
# 4/4 [==============================] - 0s 558us/step - loss: 0.1806 - accuracy: 0.7500 - mse: 0.1806
# Epoch 55/512
# 4/4 [==============================] - 0s 676us/step - loss: 0.1793 - accuracy: 0.7500 - mse: 0.1793
# Epoch 56/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1779 - accuracy: 0.7500 - mse: 0.1779
# Epoch 57/512
# 4/4 [==============================] - 0s 851us/step - loss: 0.1764 - accuracy: 0.7500 - mse: 0.1764
# Epoch 58/512
# 4/4 [==============================] - 0s 706us/step - loss: 0.1773 - accuracy: 0.7500 - mse: 0.1773
# Epoch 59/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1742 - accuracy: 0.7500 - mse: 0.1742
# Epoch 60/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.7500 - mse: 0.1751
# Epoch 61/512
# 4/4 [==============================] - 0s 850us/step - loss: 0.1717 - accuracy: 0.7500 - mse: 0.1717
# Epoch 62/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1708 - accuracy: 0.7500 - mse: 0.1708
# Epoch 63/512
# 4/4 [==============================] - 0s 754us/step - loss: 0.1700 - accuracy: 0.7500 - mse: 0.1700
# Epoch 64/512
# 4/4 [==============================] - 0s 568us/step - loss: 0.1687 - accuracy: 0.7500 - mse: 0.1687
# Epoch 65/512
# 4/4 [==============================] - 0s 433us/step - loss: 0.1701 - accuracy: 0.7500 - mse: 0.1701
# Epoch 66/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.1668 - accuracy: 0.7500 - mse: 0.1668
# Epoch 67/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1658 - accuracy: 0.7500 - mse: 0.1658
# Epoch 68/512
# 4/4 [==============================] - 0s 500us/step - loss: 0.1650 - accuracy: 0.7500 - mse: 0.1650
# Epoch 69/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.1664 - accuracy: 0.7500 - mse: 0.1664
# Epoch 70/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.1632 - accuracy: 0.7500 - mse: 0.1632
# Epoch 71/512
# 4/4 [==============================] - 0s 955us/step - loss: 0.1626 - accuracy: 0.7500 - mse: 0.1626
# Epoch 72/512
# 4/4 [==============================] - 0s 563us/step - loss: 0.1620 - accuracy: 0.7500 - mse: 0.1620
# Epoch 73/512
# 4/4 [==============================] - 0s 605us/step - loss: 0.1611 - accuracy: 0.7500 - mse: 0.1611
# Epoch 74/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.1623 - accuracy: 0.7500 - mse: 0.1623
# Epoch 75/512
# 4/4 [==============================] - 0s 440us/step - loss: 0.1593 - accuracy: 0.7500 - mse: 0.1593
# Epoch 76/512
# 4/4 [==============================] - 0s 657us/step - loss: 0.1588 - accuracy: 0.7500 - mse: 0.1588
# Epoch 77/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.1580 - accuracy: 0.7500 - mse: 0.1580
# Epoch 78/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.1572 - accuracy: 0.7500 - mse: 0.1572
# Epoch 79/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.1587 - accuracy: 0.7500 - mse: 0.1587
# Epoch 80/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1580 - accuracy: 0.7500 - mse: 0.1580
# Epoch 81/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1552 - accuracy: 0.7500 - mse: 0.1552
# Epoch 82/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.1546 - accuracy: 0.7500 - mse: 0.1546
# Epoch 83/512
# 4/4 [==============================] - 0s 523us/step - loss: 0.1563 - accuracy: 0.7500 - mse: 0.1563
# Epoch 84/512
# 4/4 [==============================] - 0s 733us/step - loss: 0.1555 - accuracy: 0.7500 - mse: 0.1555
# Epoch 85/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.1530 - accuracy: 0.7500 - mse: 0.1530
# Epoch 86/512
# 4/4 [==============================] - 0s 624us/step - loss: 0.1521 - accuracy: 0.7500 - mse: 0.1521
# Epoch 87/512
# 4/4 [==============================] - 0s 737us/step - loss: 0.1518 - accuracy: 0.7500 - mse: 0.1518
# Epoch 88/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.1510 - accuracy: 0.7500 - mse: 0.1510
# Epoch 89/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.1526 - accuracy: 0.7500 - mse: 0.1526
# Epoch 90/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.1501 - accuracy: 0.7500 - mse: 0.1501
# Epoch 91/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1493 - accuracy: 0.7500 - mse: 0.1493
# Epoch 92/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.1489 - accuracy: 0.7500 - mse: 0.1489
# Epoch 93/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.1500 - accuracy: 0.7500 - mse: 0.1500
# Epoch 94/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.1475 - accuracy: 1.0000 - mse: 0.1475
# Epoch 95/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.1473 - accuracy: 1.0000 - mse: 0.1473
# Epoch 96/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.1467 - accuracy: 1.0000 - mse: 0.1467
# Epoch 97/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.1480 - accuracy: 1.0000 - mse: 0.1480
# Epoch 98/512
# 4/4 [==============================] - 0s 735us/step - loss: 0.1455 - accuracy: 1.0000 - mse: 0.1455
# Epoch 99/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1450 - accuracy: 1.0000 - mse: 0.1450
# Epoch 100/512
# 4/4 [==============================] - 0s 433us/step - loss: 0.1463 - accuracy: 1.0000 - mse: 0.1463
# Epoch 101/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.1461 - accuracy: 1.0000 - mse: 0.1461
# Epoch 102/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.1436 - accuracy: 1.0000 - mse: 0.1436
# Epoch 103/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.1431 - accuracy: 1.0000 - mse: 0.1431
# Epoch 104/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.1425 - accuracy: 1.0000 - mse: 0.1425
# Epoch 105/512
# 4/4 [==============================] - 0s 688us/step - loss: 0.1437 - accuracy: 1.0000 - mse: 0.1437
# Epoch 106/512
# 4/4 [==============================] - 0s 623us/step - loss: 0.1414 - accuracy: 1.0000 - mse: 0.1414
# Epoch 107/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.1409 - accuracy: 1.0000 - mse: 0.1409
# Epoch 108/512
# 4/4 [==============================] - 0s 409us/step - loss: 0.1403 - accuracy: 1.0000 - mse: 0.1403
# Epoch 109/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.1401 - accuracy: 1.0000 - mse: 0.1401
# Epoch 110/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.1415 - accuracy: 1.0000 - mse: 0.1415
# Epoch 111/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.1391 - accuracy: 1.0000 - mse: 0.1391
# Epoch 112/512
# 4/4 [==============================] - 0s 413us/step - loss: 0.1384 - accuracy: 1.0000 - mse: 0.1384
# Epoch 113/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1401 - accuracy: 1.0000 - mse: 0.1401
# Epoch 114/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.1377 - accuracy: 1.0000 - mse: 0.1377
# Epoch 115/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.1391 - accuracy: 1.0000 - mse: 0.1391
# Epoch 116/512
# 4/4 [==============================] - 0s 434us/step - loss: 0.1382 - accuracy: 1.0000 - mse: 0.1382
# Epoch 117/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.1361 - accuracy: 1.0000 - mse: 0.1361
# Epoch 118/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.1355 - accuracy: 1.0000 - mse: 0.1355
# Epoch 119/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.1353 - accuracy: 1.0000 - mse: 0.1353
# Epoch 120/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1367 - accuracy: 1.0000 - mse: 0.1367
# Epoch 121/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.1362 - accuracy: 1.0000 - mse: 0.1362
# Epoch 122/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.1338 - accuracy: 1.0000 - mse: 0.1338
# Epoch 123/512
# 4/4 [==============================] - 0s 559us/step - loss: 0.1332 - accuracy: 1.0000 - mse: 0.1332
# Epoch 124/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.1327 - accuracy: 1.0000 - mse: 0.1327
# Epoch 125/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.1343 - accuracy: 1.0000 - mse: 0.1343
# Epoch 126/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.1337 - accuracy: 1.0000 - mse: 0.1337
# Epoch 127/512
# 4/4 [==============================] - 0s 582us/step - loss: 0.1334 - accuracy: 1.0000 - mse: 0.1334
# Epoch 128/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.1309 - accuracy: 1.0000 - mse: 0.1309
# Epoch 129/512
# 4/4 [==============================] - 0s 551us/step - loss: 0.1325 - accuracy: 1.0000 - mse: 0.1325
# Epoch 130/512
# 4/4 [==============================] - 0s 697us/step - loss: 0.1301 - accuracy: 1.0000 - mse: 0.1301
# Epoch 131/512
# 4/4 [==============================] - 0s 569us/step - loss: 0.1295 - accuracy: 1.0000 - mse: 0.1295
# Epoch 132/512
# 4/4 [==============================] - 0s 500us/step - loss: 0.1311 - accuracy: 1.0000 - mse: 0.1311
# Epoch 133/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.1307 - accuracy: 1.0000 - mse: 0.1307
# Epoch 134/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.1283 - accuracy: 1.0000 - mse: 0.1283
# Epoch 135/512
# 4/4 [==============================] - 0s 466us/step - loss: 0.1298 - accuracy: 1.0000 - mse: 0.1298
# Epoch 136/512
# 4/4 [==============================] - 0s 428us/step - loss: 0.1273 - accuracy: 1.0000 - mse: 0.1273
# Epoch 137/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.1269 - accuracy: 1.0000 - mse: 0.1269
# Epoch 138/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.1265 - accuracy: 1.0000 - mse: 0.1265
# Epoch 139/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.1262 - accuracy: 1.0000 - mse: 0.1262
# Epoch 140/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.1255 - accuracy: 1.0000 - mse: 0.1255
# Epoch 141/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1251 - accuracy: 1.0000 - mse: 0.1251
# Epoch 142/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.1265 - accuracy: 1.0000 - mse: 0.1265
# Epoch 143/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.1243 - accuracy: 1.0000 - mse: 0.1243
# Epoch 144/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.1241 - accuracy: 1.0000 - mse: 0.1241
# Epoch 145/512
# 4/4 [==============================] - 0s 567us/step - loss: 0.1252 - accuracy: 1.0000 - mse: 0.1252
# Epoch 146/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.1248 - accuracy: 1.0000 - mse: 0.1248
# Epoch 147/512
# 4/4 [==============================] - 0s 625us/step - loss: 0.1226 - accuracy: 1.0000 - mse: 0.1226
# Epoch 148/512
# 4/4 [==============================] - 0s 439us/step - loss: 0.1221 - accuracy: 1.0000 - mse: 0.1221
# Epoch 149/512
# 4/4 [==============================] - 0s 687us/step - loss: 0.1233 - accuracy: 1.0000 - mse: 0.1233
# Epoch 150/512
# 4/4 [==============================] - 0s 715us/step - loss: 0.1231 - accuracy: 1.0000 - mse: 0.1231
# Epoch 151/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.1208 - accuracy: 1.0000 - mse: 0.1208
# Epoch 152/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.1205 - accuracy: 1.0000 - mse: 0.1205
# Epoch 153/512
# 4/4 [==============================] - 0s 567us/step - loss: 0.1218 - accuracy: 1.0000 - mse: 0.1218
# Epoch 154/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.1211 - accuracy: 1.0000 - mse: 0.1211
# Epoch 155/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.1190 - accuracy: 1.0000 - mse: 0.1190
# Epoch 156/512
# 4/4 [==============================] - 0s 620us/step - loss: 0.1188 - accuracy: 1.0000 - mse: 0.1188
# Epoch 157/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1183 - accuracy: 1.0000 - mse: 0.1183
# Epoch 158/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.1177 - accuracy: 1.0000 - mse: 0.1177
# Epoch 159/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.1173 - accuracy: 1.0000 - mse: 0.1173
# Epoch 160/512
# 4/4 [==============================] - 0s 549us/step - loss: 0.1169 - accuracy: 1.0000 - mse: 0.1169
# Epoch 161/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.1183 - accuracy: 1.0000 - mse: 0.1183
# Epoch 162/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.1163 - accuracy: 1.0000 - mse: 0.1163
# Epoch 163/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1157 - accuracy: 1.0000 - mse: 0.1157
# Epoch 164/512
# 4/4 [==============================] - 0s 435us/step - loss: 0.1152 - accuracy: 1.0000 - mse: 0.1152
# Epoch 165/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.1150 - accuracy: 1.0000 - mse: 0.1150
# Epoch 166/512
# 4/4 [==============================] - 0s 586us/step - loss: 0.1163 - accuracy: 1.0000 - mse: 0.1163
# Epoch 167/512
# 4/4 [==============================] - 0s 535us/step - loss: 0.1140 - accuracy: 1.0000 - mse: 0.1140
# Epoch 168/512
# 4/4 [==============================] - 0s 807us/step - loss: 0.1155 - accuracy: 1.0000 - mse: 0.1155
# Epoch 169/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.1133 - accuracy: 1.0000 - mse: 0.1133
# Epoch 170/512
# 4/4 [==============================] - 0s 581us/step - loss: 0.1146 - accuracy: 1.0000 - mse: 0.1146
# Epoch 171/512
# 4/4 [==============================] - 0s 417us/step - loss: 0.1124 - accuracy: 1.0000 - mse: 0.1124
# Epoch 172/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.1138 - accuracy: 1.0000 - mse: 0.1138
# Epoch 173/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.1117 - accuracy: 1.0000 - mse: 0.1117
# Epoch 174/512
# 4/4 [==============================] - 0s 544us/step - loss: 0.1113 - accuracy: 1.0000 - mse: 0.1113
# Epoch 175/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.1109 - accuracy: 1.0000 - mse: 0.1109
# Epoch 176/512
# 4/4 [==============================] - 0s 664us/step - loss: 0.1104 - accuracy: 1.0000 - mse: 0.1104
# Epoch 177/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1101 - accuracy: 1.0000 - mse: 0.1101
# Epoch 178/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1111 - accuracy: 1.0000 - mse: 0.1111
# Epoch 179/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.1093 - accuracy: 1.0000 - mse: 0.1093
# Epoch 180/512
# 4/4 [==============================] - 0s 429us/step - loss: 0.1089 - accuracy: 1.0000 - mse: 0.1089
# Epoch 181/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.1101 - accuracy: 1.0000 - mse: 0.1101
# Epoch 182/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1095 - accuracy: 1.0000 - mse: 0.1095
# Epoch 183/512
# 4/4 [==============================] - 0s 532us/step - loss: 0.1077 - accuracy: 1.0000 - mse: 0.1077
# Epoch 184/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.1074 - accuracy: 1.0000 - mse: 0.1074
# Epoch 185/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.1070 - accuracy: 1.0000 - mse: 0.1070
# Epoch 186/512
# 4/4 [==============================] - 0s 607us/step - loss: 0.1066 - accuracy: 1.0000 - mse: 0.1066
# Epoch 187/512
# 4/4 [==============================] - 0s 618us/step - loss: 0.1076 - accuracy: 1.0000 - mse: 0.1076
# Epoch 188/512
# 4/4 [==============================] - 0s 617us/step - loss: 0.1075 - accuracy: 1.0000 - mse: 0.1075
# Epoch 189/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.1054 - accuracy: 1.0000 - mse: 0.1054
# Epoch 190/512
# 4/4 [==============================] - 0s 599us/step - loss: 0.1049 - accuracy: 1.0000 - mse: 0.1049
# Epoch 191/512
# 4/4 [==============================] - 0s 628us/step - loss: 0.1047 - accuracy: 1.0000 - mse: 0.1047
# Epoch 192/512
# 4/4 [==============================] - 0s 438us/step - loss: 0.1059 - accuracy: 1.0000 - mse: 0.1059
# Epoch 193/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.1053 - accuracy: 1.0000 - mse: 0.1053
# Epoch 194/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.1051 - accuracy: 1.0000 - mse: 0.1051
# Epoch 195/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.1029 - accuracy: 1.0000 - mse: 0.1029
# Epoch 196/512
# 4/4 [==============================] - 0s 530us/step - loss: 0.1027 - accuracy: 1.0000 - mse: 0.1027
# Epoch 197/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.1039 - accuracy: 1.0000 - mse: 0.1039
# Epoch 198/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.1018 - accuracy: 1.0000 - mse: 0.1018
# Epoch 199/512
# 4/4 [==============================] - 0s 547us/step - loss: 0.1015 - accuracy: 1.0000 - mse: 0.1015
# Epoch 200/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.1011 - accuracy: 1.0000 - mse: 0.1011
# Epoch 201/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.1023 - accuracy: 1.0000 - mse: 0.1023
# Epoch 202/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.1020 - accuracy: 1.0000 - mse: 0.1020
# Epoch 203/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.1000 - accuracy: 1.0000 - mse: 0.1000
# Epoch 204/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.1013 - accuracy: 1.0000 - mse: 0.1013
# Epoch 205/512
# 4/4 [==============================] - 0s 676us/step - loss: 0.0992 - accuracy: 1.0000 - mse: 0.0992
# Epoch 206/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.0991 - accuracy: 1.0000 - mse: 0.0991
# Epoch 207/512
# 4/4 [==============================] - 0s 815us/step - loss: 0.0985 - accuracy: 1.0000 - mse: 0.0985
# Epoch 208/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.0984 - accuracy: 1.0000 - mse: 0.0984
# Epoch 209/512
# 4/4 [==============================] - 0s 431us/step - loss: 0.0978 - accuracy: 1.0000 - mse: 0.0978
# Epoch 210/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.0975 - accuracy: 1.0000 - mse: 0.0975
# Epoch 211/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.0987 - accuracy: 1.0000 - mse: 0.0987
# Epoch 212/512
# 4/4 [==============================] - 0s 652us/step - loss: 0.0981 - accuracy: 1.0000 - mse: 0.0981
# Epoch 213/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0965 - accuracy: 1.0000 - mse: 0.0965
# Epoch 214/512
# 4/4 [==============================] - 0s 429us/step - loss: 0.0974 - accuracy: 1.0000 - mse: 0.0974
# Epoch 215/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.0956 - accuracy: 1.0000 - mse: 0.0956
# Epoch 216/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.0953 - accuracy: 1.0000 - mse: 0.0953
# Epoch 217/512
# 4/4 [==============================] - 0s 449us/step - loss: 0.0966 - accuracy: 1.0000 - mse: 0.0966
# Epoch 218/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.0947 - accuracy: 1.0000 - mse: 0.0947
# Epoch 219/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0941 - accuracy: 1.0000 - mse: 0.0941
# Epoch 220/512
# 4/4 [==============================] - 0s 523us/step - loss: 0.0940 - accuracy: 1.0000 - mse: 0.0940
# Epoch 221/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.0935 - accuracy: 1.0000 - mse: 0.0935
# Epoch 222/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0947 - accuracy: 1.0000 - mse: 0.0947
# Epoch 223/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0941 - accuracy: 1.0000 - mse: 0.0941
# Epoch 224/512
# 4/4 [==============================] - 0s 678us/step - loss: 0.0939 - accuracy: 1.0000 - mse: 0.0939
# Epoch 225/512
# 4/4 [==============================] - 0s 739us/step - loss: 0.0921 - accuracy: 1.0000 - mse: 0.0921
# Epoch 226/512
# 4/4 [==============================] - 0s 605us/step - loss: 0.0930 - accuracy: 1.0000 - mse: 0.0930
# Epoch 227/512
# 4/4 [==============================] - 0s 591us/step - loss: 0.0914 - accuracy: 1.0000 - mse: 0.0914
# Epoch 228/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.0925 - accuracy: 1.0000 - mse: 0.0925
# Epoch 229/512
# 4/4 [==============================] - 0s 439us/step - loss: 0.0920 - accuracy: 1.0000 - mse: 0.0920
# Epoch 230/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.0903 - accuracy: 1.0000 - mse: 0.0903
# Epoch 231/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.0914 - accuracy: 1.0000 - mse: 0.0914
# Epoch 232/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.0898 - accuracy: 1.0000 - mse: 0.0898
# Epoch 233/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.0893 - accuracy: 1.0000 - mse: 0.0893
# Epoch 234/512
# 4/4 [==============================] - 0s 633us/step - loss: 0.0890 - accuracy: 1.0000 - mse: 0.0890
# Epoch 235/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.0886 - accuracy: 1.0000 - mse: 0.0886
# Epoch 236/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.0883 - accuracy: 1.0000 - mse: 0.0883
# Epoch 237/512
# 4/4 [==============================] - 0s 698us/step - loss: 0.0879 - accuracy: 1.0000 - mse: 0.0879
# Epoch 238/512
# 4/4 [==============================] - 0s 571us/step - loss: 0.0875 - accuracy: 1.0000 - mse: 0.0875
# Epoch 239/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.0871 - accuracy: 1.0000 - mse: 0.0871
# Epoch 240/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.0870 - accuracy: 1.0000 - mse: 0.0870
# Epoch 241/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.0878 - accuracy: 1.0000 - mse: 0.0878
# Epoch 242/512
# 4/4 [==============================] - 0s 616us/step - loss: 0.0876 - accuracy: 1.0000 - mse: 0.0876
# Epoch 243/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.0872 - accuracy: 1.0000 - mse: 0.0872
# Epoch 244/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.0855 - accuracy: 1.0000 - mse: 0.0855
# Epoch 245/512
# 4/4 [==============================] - 0s 659us/step - loss: 0.0852 - accuracy: 1.0000 - mse: 0.0852
# Epoch 246/512
# 4/4 [==============================] - 0s 407us/step - loss: 0.0848 - accuracy: 1.0000 - mse: 0.0848
# Epoch 247/512
# 4/4 [==============================] - 0s 471us/step - loss: 0.0859 - accuracy: 1.0000 - mse: 0.0859
# Epoch 248/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.0843 - accuracy: 1.0000 - mse: 0.0843
# Epoch 249/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.0838 - accuracy: 1.0000 - mse: 0.0838
# Epoch 250/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.0849 - accuracy: 1.0000 - mse: 0.0849
# Epoch 251/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.0833 - accuracy: 1.0000 - mse: 0.0833
# Epoch 252/512
# 4/4 [==============================] - 0s 620us/step - loss: 0.0828 - accuracy: 1.0000 - mse: 0.0828
# Epoch 253/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.0839 - accuracy: 1.0000 - mse: 0.0839
# Epoch 254/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.0835 - accuracy: 1.0000 - mse: 0.0835
# Epoch 255/512
# 4/4 [==============================] - 0s 541us/step - loss: 0.0819 - accuracy: 1.0000 - mse: 0.0819
# Epoch 256/512
# 4/4 [==============================] - 0s 944us/step - loss: 0.0815 - accuracy: 1.0000 - mse: 0.0815
# Epoch 257/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.0811 - accuracy: 1.0000 - mse: 0.0811
# Epoch 258/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.0810 - accuracy: 1.0000 - mse: 0.0810
# Epoch 259/512
# 4/4 [==============================] - 0s 700us/step - loss: 0.0806 - accuracy: 1.0000 - mse: 0.0806
# Epoch 260/512
# 4/4 [==============================] - 0s 621us/step - loss: 0.0803 - accuracy: 1.0000 - mse: 0.0803
# Epoch 261/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.0801 - accuracy: 1.0000 - mse: 0.0801
# Epoch 262/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.0797 - accuracy: 1.0000 - mse: 0.0797
# Epoch 263/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.0793 - accuracy: 1.0000 - mse: 0.0793
# Epoch 264/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.0790 - accuracy: 1.0000 - mse: 0.0790
# Epoch 265/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.0788 - accuracy: 1.0000 - mse: 0.0788
# Epoch 266/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0797 - accuracy: 1.0000 - mse: 0.0797
# Epoch 267/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.0792 - accuracy: 1.0000 - mse: 0.0792
# Epoch 268/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.0791 - accuracy: 1.0000 - mse: 0.0791
# Epoch 269/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.0776 - accuracy: 1.0000 - mse: 0.0776
# Epoch 270/512
# 4/4 [==============================] - 0s 437us/step - loss: 0.0785 - accuracy: 1.0000 - mse: 0.0785
# Epoch 271/512
# 4/4 [==============================] - 0s 744us/step - loss: 0.0769 - accuracy: 1.0000 - mse: 0.0769
# Epoch 272/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.0766 - accuracy: 1.0000 - mse: 0.0766
# Epoch 273/512
# 4/4 [==============================] - 0s 509us/step - loss: 0.0776 - accuracy: 1.0000 - mse: 0.0776
# Epoch 274/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.0759 - accuracy: 1.0000 - mse: 0.0759
# Epoch 275/512
# 4/4 [==============================] - 0s 580us/step - loss: 0.0756 - accuracy: 1.0000 - mse: 0.0756
# Epoch 276/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.0753 - accuracy: 1.0000 - mse: 0.0753
# Epoch 277/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.0750 - accuracy: 1.0000 - mse: 0.0750
# Epoch 278/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.0748 - accuracy: 1.0000 - mse: 0.0748
# Epoch 279/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.0744 - accuracy: 1.0000 - mse: 0.0744
# Epoch 280/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.0754 - accuracy: 1.0000 - mse: 0.0754
# Epoch 281/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.0739 - accuracy: 1.0000 - mse: 0.0739
# Epoch 282/512
# 4/4 [==============================] - 0s 558us/step - loss: 0.0735 - accuracy: 1.0000 - mse: 0.0735
# Epoch 283/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0733 - accuracy: 1.0000 - mse: 0.0733
# Epoch 284/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.0730 - accuracy: 1.0000 - mse: 0.0730
# Epoch 285/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.0726 - accuracy: 1.0000 - mse: 0.0726
# Epoch 286/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.0725 - accuracy: 1.0000 - mse: 0.0725
# Epoch 287/512
# 4/4 [==============================] - 0s 530us/step - loss: 0.0721 - accuracy: 1.0000 - mse: 0.0721
# Epoch 288/512
# 4/4 [==============================] - 0s 542us/step - loss: 0.0729 - accuracy: 1.0000 - mse: 0.0729
# Epoch 289/512
# 4/4 [==============================] - 0s 434us/step - loss: 0.0715 - accuracy: 1.0000 - mse: 0.0715
# Epoch 290/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.0725 - accuracy: 1.0000 - mse: 0.0725
# Epoch 291/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.0710 - accuracy: 1.0000 - mse: 0.0710
# Epoch 292/512
# 4/4 [==============================] - 0s 654us/step - loss: 0.0706 - accuracy: 1.0000 - mse: 0.0706
# Epoch 293/512
# 4/4 [==============================] - 0s 620us/step - loss: 0.0716 - accuracy: 1.0000 - mse: 0.0716
# Epoch 294/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0711 - accuracy: 1.0000 - mse: 0.0711
# Epoch 295/512
# 4/4 [==============================] - 0s 456us/step - loss: 0.0708 - accuracy: 1.0000 - mse: 0.0708
# Epoch 296/512
# 4/4 [==============================] - 0s 625us/step - loss: 0.0705 - accuracy: 1.0000 - mse: 0.0705
# Epoch 297/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.0702 - accuracy: 1.0000 - mse: 0.0702
# Epoch 298/512
# 4/4 [==============================] - 0s 566us/step - loss: 0.0701 - accuracy: 1.0000 - mse: 0.0701
# Epoch 299/512
# 4/4 [==============================] - 0s 566us/step - loss: 0.0686 - accuracy: 1.0000 - mse: 0.0686
# Epoch 300/512
# 4/4 [==============================] - 0s 456us/step - loss: 0.0683 - accuracy: 1.0000 - mse: 0.0683
# Epoch 301/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.0692 - accuracy: 1.0000 - mse: 0.0692
# Epoch 302/512
# 4/4 [==============================] - 0s 429us/step - loss: 0.0687 - accuracy: 1.0000 - mse: 0.0687
# Epoch 303/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.0685 - accuracy: 1.0000 - mse: 0.0685
# Epoch 304/512
# 4/4 [==============================] - 0s 535us/step - loss: 0.0672 - accuracy: 1.0000 - mse: 0.0672
# Epoch 305/512
# 4/4 [==============================] - 0s 551us/step - loss: 0.0680 - accuracy: 1.0000 - mse: 0.0680
# Epoch 306/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.0667 - accuracy: 1.0000 - mse: 0.0667
# Epoch 307/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.0674 - accuracy: 1.0000 - mse: 0.0674
# Epoch 308/512
# 4/4 [==============================] - 0s 643us/step - loss: 0.0661 - accuracy: 1.0000 - mse: 0.0661
# Epoch 309/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.0658 - accuracy: 1.0000 - mse: 0.0658
# Epoch 310/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.0655 - accuracy: 1.0000 - mse: 0.0655
# Epoch 311/512
# 4/4 [==============================] - 0s 418us/step - loss: 0.0653 - accuracy: 1.0000 - mse: 0.0653
# Epoch 312/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.0661 - accuracy: 1.0000 - mse: 0.0661
# Epoch 313/512
# 4/4 [==============================] - 0s 545us/step - loss: 0.0648 - accuracy: 1.0000 - mse: 0.0648
# Epoch 314/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.0654 - accuracy: 1.0000 - mse: 0.0654
# Epoch 315/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.0653 - accuracy: 1.0000 - mse: 0.0653
# Epoch 316/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0638 - accuracy: 1.0000 - mse: 0.0638
# Epoch 317/512
# 4/4 [==============================] - 0s 538us/step - loss: 0.0645 - accuracy: 1.0000 - mse: 0.0645
# Epoch 318/512
# 4/4 [==============================] - 0s 679us/step - loss: 0.0634 - accuracy: 1.0000 - mse: 0.0634
# Epoch 319/512
# 4/4 [==============================] - 0s 646us/step - loss: 0.0631 - accuracy: 1.0000 - mse: 0.0631
# Epoch 320/512
# 4/4 [==============================] - 0s 525us/step - loss: 0.0628 - accuracy: 1.0000 - mse: 0.0628
# Epoch 321/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.0626 - accuracy: 1.0000 - mse: 0.0626
# Epoch 322/512
# 4/4 [==============================] - 0s 584us/step - loss: 0.0622 - accuracy: 1.0000 - mse: 0.0622
# Epoch 323/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.0620 - accuracy: 1.0000 - mse: 0.0620
# Epoch 324/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.0617 - accuracy: 1.0000 - mse: 0.0617
# Epoch 325/512
# 4/4 [==============================] - 0s 448us/step - loss: 0.0626 - accuracy: 1.0000 - mse: 0.0626
# Epoch 326/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.0613 - accuracy: 1.0000 - mse: 0.0613
# Epoch 327/512
# 4/4 [==============================] - 0s 593us/step - loss: 0.0610 - accuracy: 1.0000 - mse: 0.0610
# Epoch 328/512
# 4/4 [==============================] - 0s 551us/step - loss: 0.0607 - accuracy: 1.0000 - mse: 0.0607
# Epoch 329/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.0604 - accuracy: 1.0000 - mse: 0.0604
# Epoch 330/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.0602 - accuracy: 1.0000 - mse: 0.0602
# Epoch 331/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0600 - accuracy: 1.0000 - mse: 0.0600
# Epoch 332/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.0597 - accuracy: 1.0000 - mse: 0.0597
# Epoch 333/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0594 - accuracy: 1.0000 - mse: 0.0594
# Epoch 334/512
# 4/4 [==============================] - 0s 715us/step - loss: 0.0592 - accuracy: 1.0000 - mse: 0.0592
# Epoch 335/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.0599 - accuracy: 1.0000 - mse: 0.0599
# Epoch 336/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.0588 - accuracy: 1.0000 - mse: 0.0588
# Epoch 337/512
# 4/4 [==============================] - 0s 608us/step - loss: 0.0584 - accuracy: 1.0000 - mse: 0.0584
# Epoch 338/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0581 - accuracy: 1.0000 - mse: 0.0581
# Epoch 339/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.0589 - accuracy: 1.0000 - mse: 0.0589
# Epoch 340/512
# 4/4 [==============================] - 0s 571us/step - loss: 0.0586 - accuracy: 1.0000 - mse: 0.0586
# Epoch 341/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.0574 - accuracy: 1.0000 - mse: 0.0574
# Epoch 342/512
# 4/4 [==============================] - 0s 598us/step - loss: 0.0572 - accuracy: 1.0000 - mse: 0.0572
# Epoch 343/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.0579 - accuracy: 1.0000 - mse: 0.0579
# Epoch 344/512
# 4/4 [==============================] - 0s 412us/step - loss: 0.0568 - accuracy: 1.0000 - mse: 0.0568
# Epoch 345/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.0564 - accuracy: 1.0000 - mse: 0.0564
# Epoch 346/512
# 4/4 [==============================] - 0s 410us/step - loss: 0.0572 - accuracy: 1.0000 - mse: 0.0572
# Epoch 347/512
# 4/4 [==============================] - 0s 397us/step - loss: 0.0560 - accuracy: 1.0000 - mse: 0.0560
# Epoch 348/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.0565 - accuracy: 1.0000 - mse: 0.0565
# Epoch 349/512
# 4/4 [==============================] - 0s 572us/step - loss: 0.0554 - accuracy: 1.0000 - mse: 0.0554
# Epoch 350/512
# 4/4 [==============================] - 0s 448us/step - loss: 0.0559 - accuracy: 1.0000 - mse: 0.0559
# Epoch 351/512
# 4/4 [==============================] - 0s 813us/step - loss: 0.0549 - accuracy: 1.0000 - mse: 0.0549
# Epoch 352/512
# 4/4 [==============================] - 0s 885us/step - loss: 0.0556 - accuracy: 1.0000 - mse: 0.0556
# Epoch 353/512
# 4/4 [==============================] - 0s 471us/step - loss: 0.0554 - accuracy: 1.0000 - mse: 0.0554
# Epoch 354/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.0550 - accuracy: 1.0000 - mse: 0.0550
# Epoch 355/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.0549 - accuracy: 1.0000 - mse: 0.0549
# Epoch 356/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0537 - accuracy: 1.0000 - mse: 0.0537
# Epoch 357/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.0535 - accuracy: 1.0000 - mse: 0.0535
# Epoch 358/512
# 4/4 [==============================] - 0s 765us/step - loss: 0.0533 - accuracy: 1.0000 - mse: 0.0533
# Epoch 359/512
# 4/4 [==============================] - 0s 555us/step - loss: 0.0531 - accuracy: 1.0000 - mse: 0.0531
# Epoch 360/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.0537 - accuracy: 1.0000 - mse: 0.0537
# Epoch 361/512
# 4/4 [==============================] - 0s 596us/step - loss: 0.0534 - accuracy: 1.0000 - mse: 0.0534
# Epoch 362/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.0531 - accuracy: 1.0000 - mse: 0.0531
# Epoch 363/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.0521 - accuracy: 1.0000 - mse: 0.0521
# Epoch 364/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.0519 - accuracy: 1.0000 - mse: 0.0519
# Epoch 365/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0516 - accuracy: 1.0000 - mse: 0.0516
# Epoch 366/512
# 4/4 [==============================] - 0s 622us/step - loss: 0.0514 - accuracy: 1.0000 - mse: 0.0514
# Epoch 367/512
# 4/4 [==============================] - 0s 615us/step - loss: 0.0511 - accuracy: 1.0000 - mse: 0.0511
# Epoch 368/512
# 4/4 [==============================] - 0s 762us/step - loss: 0.0509 - accuracy: 1.0000 - mse: 0.0509
# Epoch 369/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.0507 - accuracy: 1.0000 - mse: 0.0507
# Epoch 370/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.0514 - accuracy: 1.0000 - mse: 0.0514
# Epoch 371/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0509 - accuracy: 1.0000 - mse: 0.0509
# Epoch 372/512
# 4/4 [==============================] - 0s 423us/step - loss: 0.0508 - accuracy: 1.0000 - mse: 0.0508
# Epoch 373/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.0498 - accuracy: 1.0000 - mse: 0.0498
# Epoch 374/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.0504 - accuracy: 1.0000 - mse: 0.0504
# Epoch 375/512
# 4/4 [==============================] - 0s 587us/step - loss: 0.0493 - accuracy: 1.0000 - mse: 0.0493
# Epoch 376/512
# 4/4 [==============================] - 0s 575us/step - loss: 0.0492 - accuracy: 1.0000 - mse: 0.0492
# Epoch 377/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.0489 - accuracy: 1.0000 - mse: 0.0489
# Epoch 378/512
# 4/4 [==============================] - 0s 711us/step - loss: 0.0487 - accuracy: 1.0000 - mse: 0.0487
# Epoch 379/512
# 4/4 [==============================] - 0s 592us/step - loss: 0.0485 - accuracy: 1.0000 - mse: 0.0485
# Epoch 380/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.0490 - accuracy: 1.0000 - mse: 0.0490
# Epoch 381/512
# 4/4 [==============================] - 0s 700us/step - loss: 0.0480 - accuracy: 1.0000 - mse: 0.0480
# Epoch 382/512
# 4/4 [==============================] - 0s 809us/step - loss: 0.0487 - accuracy: 1.0000 - mse: 0.0487
# Epoch 383/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.0476 - accuracy: 1.0000 - mse: 0.0476
# Epoch 384/512
# 4/4 [==============================] - 0s 449us/step - loss: 0.0482 - accuracy: 1.0000 - mse: 0.0482
# Epoch 385/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.0472 - accuracy: 1.0000 - mse: 0.0472
# Epoch 386/512
# 4/4 [==============================] - 0s 429us/step - loss: 0.0470 - accuracy: 1.0000 - mse: 0.0470
# Epoch 387/512
# 4/4 [==============================] - 0s 541us/step - loss: 0.0467 - accuracy: 1.0000 - mse: 0.0467
# Epoch 388/512
# 4/4 [==============================] - 0s 421us/step - loss: 0.0473 - accuracy: 1.0000 - mse: 0.0473
# Epoch 389/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.0469 - accuracy: 1.0000 - mse: 0.0469
# Epoch 390/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.0461 - accuracy: 1.0000 - mse: 0.0461
# Epoch 391/512
# 4/4 [==============================] - 0s 597us/step - loss: 0.0459 - accuracy: 1.0000 - mse: 0.0459
# Epoch 392/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.0457 - accuracy: 1.0000 - mse: 0.0457
# Epoch 393/512
# 4/4 [==============================] - 0s 589us/step - loss: 0.0455 - accuracy: 1.0000 - mse: 0.0455
# Epoch 394/512
# 4/4 [==============================] - 0s 737us/step - loss: 0.0461 - accuracy: 1.0000 - mse: 0.0461
# Epoch 395/512
# 4/4 [==============================] - 0s 615us/step - loss: 0.0451 - accuracy: 1.0000 - mse: 0.0451
# Epoch 396/512
# 4/4 [==============================] - 0s 646us/step - loss: 0.0449 - accuracy: 1.0000 - mse: 0.0449
# Epoch 397/512
# 4/4 [==============================] - 0s 592us/step - loss: 0.0446 - accuracy: 1.0000 - mse: 0.0446
# Epoch 398/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0444 - accuracy: 1.0000 - mse: 0.0444
# Epoch 399/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.0450 - accuracy: 1.0000 - mse: 0.0450
# Epoch 400/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0440 - accuracy: 1.0000 - mse: 0.0440
# Epoch 401/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.0438 - accuracy: 1.0000 - mse: 0.0438
# Epoch 402/512
# 4/4 [==============================] - 0s 606us/step - loss: 0.0436 - accuracy: 1.0000 - mse: 0.0436
# Epoch 403/512
# 4/4 [==============================] - 0s 631us/step - loss: 0.0434 - accuracy: 1.0000 - mse: 0.0434
# Epoch 404/512
# 4/4 [==============================] - 0s 808us/step - loss: 0.0433 - accuracy: 1.0000 - mse: 0.0433
# Epoch 405/512
# 4/4 [==============================] - 0s 601us/step - loss: 0.0430 - accuracy: 1.0000 - mse: 0.0430
# Epoch 406/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.0427 - accuracy: 1.0000 - mse: 0.0427
# Epoch 407/512
# 4/4 [==============================] - 0s 630us/step - loss: 0.0433 - accuracy: 1.0000 - mse: 0.0433
# Epoch 408/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.0432 - accuracy: 1.0000 - mse: 0.0432
# Epoch 409/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0428 - accuracy: 1.0000 - mse: 0.0428
# Epoch 410/512
# 4/4 [==============================] - 0s 505us/step - loss: 0.0421 - accuracy: 1.0000 - mse: 0.0421
# Epoch 411/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.0425 - accuracy: 1.0000 - mse: 0.0425
# Epoch 412/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.0416 - accuracy: 1.0000 - mse: 0.0416
# Epoch 413/512
# 4/4 [==============================] - 0s 580us/step - loss: 0.0414 - accuracy: 1.0000 - mse: 0.0414
# Epoch 414/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.0412 - accuracy: 1.0000 - mse: 0.0412
# Epoch 415/512
# 4/4 [==============================] - 0s 740us/step - loss: 0.0411 - accuracy: 1.0000 - mse: 0.0411
# Epoch 416/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.0415 - accuracy: 1.0000 - mse: 0.0415
# Epoch 417/512
# 4/4 [==============================] - 0s 898us/step - loss: 0.0414 - accuracy: 1.0000 - mse: 0.0414
# Epoch 418/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.0405 - accuracy: 1.0000 - mse: 0.0405
# Epoch 419/512
# 4/4 [==============================] - 0s 435us/step - loss: 0.0403 - accuracy: 1.0000 - mse: 0.0403
# Epoch 420/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.0401 - accuracy: 1.0000 - mse: 0.0401
# Epoch 421/512
# 4/4 [==============================] - 0s 544us/step - loss: 0.0398 - accuracy: 1.0000 - mse: 0.0398
# Epoch 422/512
# 4/4 [==============================] - 0s 577us/step - loss: 0.0397 - accuracy: 1.0000 - mse: 0.0397
# Epoch 423/512
# 4/4 [==============================] - 0s 576us/step - loss: 0.0395 - accuracy: 1.0000 - mse: 0.0395
# Epoch 424/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.0394 - accuracy: 1.0000 - mse: 0.0394
# Epoch 425/512
# 4/4 [==============================] - 0s 841us/step - loss: 0.0392 - accuracy: 1.0000 - mse: 0.0392
# Epoch 426/512
# 4/4 [==============================] - 0s 698us/step - loss: 0.0389 - accuracy: 1.0000 - mse: 0.0389
# Epoch 427/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.0395 - accuracy: 1.0000 - mse: 0.0395
# Epoch 428/512
# 4/4 [==============================] - 0s 426us/step - loss: 0.0386 - accuracy: 1.0000 - mse: 0.0386
# Epoch 429/512
# 4/4 [==============================] - 0s 456us/step - loss: 0.0384 - accuracy: 1.0000 - mse: 0.0384
# Epoch 430/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.0382 - accuracy: 1.0000 - mse: 0.0382
# Epoch 431/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.0381 - accuracy: 1.0000 - mse: 0.0381
# Epoch 432/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.0386 - accuracy: 1.0000 - mse: 0.0386
# Epoch 433/512
# 4/4 [==============================] - 0s 605us/step - loss: 0.0383 - accuracy: 1.0000 - mse: 0.0383
# Epoch 434/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.0375 - accuracy: 1.0000 - mse: 0.0375
# Epoch 435/512
# 4/4 [==============================] - 0s 548us/step - loss: 0.0373 - accuracy: 1.0000 - mse: 0.0373
# Epoch 436/512
# 4/4 [==============================] - 0s 574us/step - loss: 0.0372 - accuracy: 1.0000 - mse: 0.0372
# Epoch 437/512
# 4/4 [==============================] - 0s 828us/step - loss: 0.0370 - accuracy: 1.0000 - mse: 0.0370
# Epoch 438/512
# 4/4 [==============================] - 0s 687us/step - loss: 0.0368 - accuracy: 1.0000 - mse: 0.0368
# Epoch 439/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.0367 - accuracy: 1.0000 - mse: 0.0367
# Epoch 440/512
# 4/4 [==============================] - 0s 652us/step - loss: 0.0370 - accuracy: 1.0000 - mse: 0.0370
# Epoch 441/512
# 4/4 [==============================] - 0s 675us/step - loss: 0.0370 - accuracy: 1.0000 - mse: 0.0370
# Epoch 442/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.0367 - accuracy: 1.0000 - mse: 0.0367
# Epoch 443/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.0360 - accuracy: 1.0000 - mse: 0.0360
# Epoch 444/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.0365 - accuracy: 1.0000 - mse: 0.0365
# Epoch 445/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.0362 - accuracy: 1.0000 - mse: 0.0362
# Epoch 446/512
# 4/4 [==============================] - 0s 566us/step - loss: 0.0361 - accuracy: 1.0000 - mse: 0.0361
# Epoch 447/512
# 4/4 [==============================] - 0s 851us/step - loss: 0.0354 - accuracy: 1.0000 - mse: 0.0354
# Epoch 448/512
# 4/4 [==============================] - 0s 610us/step - loss: 0.0358 - accuracy: 1.0000 - mse: 0.0358
# Epoch 449/512
# 4/4 [==============================] - 0s 544us/step - loss: 0.0355 - accuracy: 1.0000 - mse: 0.0355
# Epoch 450/512
# 4/4 [==============================] - 0s 547us/step - loss: 0.0354 - accuracy: 1.0000 - mse: 0.0354
# Epoch 451/512
# 4/4 [==============================] - 0s 663us/step - loss: 0.0352 - accuracy: 1.0000 - mse: 0.0352
# Epoch 452/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 1.0000 - mse: 0.0345
# Epoch 453/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.0344 - accuracy: 1.0000 - mse: 0.0344
# Epoch 454/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.0341 - accuracy: 1.0000 - mse: 0.0341
# Epoch 455/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.0346 - accuracy: 1.0000 - mse: 0.0346
# Epoch 456/512
# 4/4 [==============================] - 0s 536us/step - loss: 0.0339 - accuracy: 1.0000 - mse: 0.0339
# Epoch 457/512
# 4/4 [==============================] - 0s 623us/step - loss: 0.0341 - accuracy: 1.0000 - mse: 0.0341
# Epoch 458/512
# 4/4 [==============================] - 0s 471us/step - loss: 0.0336 - accuracy: 1.0000 - mse: 0.0336
# Epoch 459/512
# 4/4 [==============================] - 0s 716us/step - loss: 0.0334 - accuracy: 1.0000 - mse: 0.0334
# Epoch 460/512
# 4/4 [==============================] - 0s 647us/step - loss: 0.0333 - accuracy: 1.0000 - mse: 0.0333
# Epoch 461/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.0337 - accuracy: 1.0000 - mse: 0.0337
# Epoch 462/512
# 4/4 [==============================] - 0s 515us/step - loss: 0.0335 - accuracy: 1.0000 - mse: 0.0335
# Epoch 463/512
# 4/4 [==============================] - 0s 609us/step - loss: 0.0329 - accuracy: 1.0000 - mse: 0.0329
# Epoch 464/512
# 4/4 [==============================] - 0s 563us/step - loss: 0.0327 - accuracy: 1.0000 - mse: 0.0327
# Epoch 465/512
# 4/4 [==============================] - 0s 585us/step - loss: 0.0330 - accuracy: 1.0000 - mse: 0.0330
# Epoch 466/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.0324 - accuracy: 1.0000 - mse: 0.0324
# Epoch 467/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.0327 - accuracy: 1.0000 - mse: 0.0327
# Epoch 468/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.0321 - accuracy: 1.0000 - mse: 0.0321
# Epoch 469/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.0319 - accuracy: 1.0000 - mse: 0.0319
# Epoch 470/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.0323 - accuracy: 1.0000 - mse: 0.0323
# Epoch 471/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.0317 - accuracy: 1.0000 - mse: 0.0317
# Epoch 472/512
# 4/4 [==============================] - 0s 835us/step - loss: 0.0315 - accuracy: 1.0000 - mse: 0.0315
# Epoch 473/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.0313 - accuracy: 1.0000 - mse: 0.0313
# Epoch 474/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.0318 - accuracy: 1.0000 - mse: 0.0318
# Epoch 475/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.0311 - accuracy: 1.0000 - mse: 0.0311
# Epoch 476/512
# 4/4 [==============================] - 0s 751us/step - loss: 0.0309 - accuracy: 1.0000 - mse: 0.0309
# Epoch 477/512
# 4/4 [==============================] - 0s 654us/step - loss: 0.0313 - accuracy: 1.0000 - mse: 0.0313
# Epoch 478/512
# 4/4 [==============================] - 0s 448us/step - loss: 0.0306 - accuracy: 1.0000 - mse: 0.0306
# Epoch 479/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.0305 - accuracy: 1.0000 - mse: 0.0305
# Epoch 480/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.0303 - accuracy: 1.0000 - mse: 0.0303
# Epoch 481/512
# 4/4 [==============================] - 0s 584us/step - loss: 0.0301 - accuracy: 1.0000 - mse: 0.0301
# Epoch 482/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.0306 - accuracy: 1.0000 - mse: 0.0306
# Epoch 483/512
# 4/4 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 1.0000 - mse: 0.04 - 0s 602us/step - loss: 0.0299 - accuracy: 1.0000 - mse: 0.0299
# Epoch 484/512
# 4/4 [==============================] - 0s 656us/step - loss: 0.0298 - accuracy: 1.0000 - mse: 0.0298
# Epoch 485/512
# 4/4 [==============================] - 0s 638us/step - loss: 0.0300 - accuracy: 1.0000 - mse: 0.0300
# Epoch 486/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.0300 - accuracy: 1.0000 - mse: 0.0300
# Epoch 487/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.0298 - accuracy: 1.0000 - mse: 0.0298
# Epoch 488/512
# 4/4 [==============================] - 0s 542us/step - loss: 0.0292 - accuracy: 1.0000 - mse: 0.0292
# Epoch 489/512
# 4/4 [==============================] - 0s 430us/step - loss: 0.0296 - accuracy: 1.0000 - mse: 0.0296
# Epoch 490/512
# 4/4 [==============================] - 0s 424us/step - loss: 0.0294 - accuracy: 1.0000 - mse: 0.0294
# Epoch 491/512
# 4/4 [==============================] - 0s 608us/step - loss: 0.0292 - accuracy: 1.0000 - mse: 0.0292
# Epoch 492/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.0287 - accuracy: 1.0000 - mse: 0.0287
# Epoch 493/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.0285 - accuracy: 1.0000 - mse: 0.0285
# Epoch 494/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.0284 - accuracy: 1.0000 - mse: 0.0284
# Epoch 495/512
# 4/4 [==============================] - 0s 623us/step - loss: 0.0288 - accuracy: 1.0000 - mse: 0.0288
# Epoch 496/512
# 4/4 [==============================] - 0s 784us/step - loss: 0.0286 - accuracy: 1.0000 - mse: 0.0286
# Epoch 497/512
# 4/4 [==============================] - 0s 765us/step - loss: 0.0280 - accuracy: 1.0000 - mse: 0.0280
# Epoch 498/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.0278 - accuracy: 1.0000 - mse: 0.0278
# Epoch 499/512
# 4/4 [==============================] - 0s 471us/step - loss: 0.0278 - accuracy: 1.0000 - mse: 0.0278
# Epoch 500/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.0276 - accuracy: 1.0000 - mse: 0.0276
# Epoch 501/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.0279 - accuracy: 1.0000 - mse: 0.0279
# Epoch 502/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.0274 - accuracy: 1.0000 - mse: 0.0274
# Epoch 503/512
# 4/4 [==============================] - 0s 576us/step - loss: 0.0277 - accuracy: 1.0000 - mse: 0.0277
# Epoch 504/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.0275 - accuracy: 1.0000 - mse: 0.0275
# Epoch 505/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.0273 - accuracy: 1.0000 - mse: 0.0273
# Epoch 506/512
# 4/4 [==============================] - 0s 545us/step - loss: 0.0268 - accuracy: 1.0000 - mse: 0.0268
# Epoch 507/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.0267 - accuracy: 1.0000 - mse: 0.0267
# Epoch 508/512
# 4/4 [==============================] - 0s 598us/step - loss: 0.0271 - accuracy: 1.0000 - mse: 0.0271
# Epoch 509/512
# 4/4 [==============================] - 0s 665us/step - loss: 0.0268 - accuracy: 1.0000 - mse: 0.0268
# Epoch 510/512
# 4/4 [==============================] - 0s 641us/step - loss: 0.0267 - accuracy: 1.0000 - mse: 0.0267
# Epoch 511/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.0266 - accuracy: 1.0000 - mse: 0.0266
# Epoch 512/512
# 4/4 [==============================] - 0s 603us/step - loss: 0.0264 - accuracy: 1.0000 - mse: 0.0264

# %% [markdown]
# Note above that we've made it easy to vary the number of epochs.  This is worth exploring after we first cover some basics starting with tools to summarize the model fitting process.
#
# To start, ```summary``` will give an overview of the network, including how many parameters are used.  The ```None``` in the Output Shape column corresponds to the number of input values fed through the network.  ```summary``` must be called *after* ```fit```.

# %%
network1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# If we want to inspect where the weights are stored in a network we can use the ```_layers``` attribute of the network:

# %%
network1._layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7ff5397d8750>,
#  <keras.layers.core.Dense at 0x7ff53979b810>,
#  <keras.layers.core.Dense at 0x7ff53979b590>]

# %% [markdown]
# Each of the elements in this list represents the things associated with one of the layers of the network.  The ```InputLayer``` doesn't actually interest us (it deals with reading in data), but we can look at the weights of the hidden layer:

# %%
foo = network1._layers[1].weights
foo
# Out:
# [<tf.Variable 'dense_1/kernel:0' shape=(2, 10) dtype=float32>,
#  <tf.Variable 'dense_1/bias:0' shape=(10,) dtype=float32>]

# %% [markdown]
# But it is **important** to take a moment and realize these weights are more than just a numpy array.  Seen as displayed above they are a data structre that came into existence when the network was compiled. But, they actually only have weight values after fitting.  And here is ow you can examine (after fitting) the weights themselves.

# %%
foo = network1._layers[1].get_weights()
foo
# Out:
# [array([[ 0.3604646 ,  0.18683968, -0.39998972, -0.04440126,  0.6293088 ,
#          -0.31519082, -0.4126721 ,  0.32252824,  0.34899023, -0.6286477 ],
#         [-0.5048781 , -0.18634614,  0.40049204,  0.15652823, -0.66271317,
#          -0.0705983 , -0.683647  , -0.32200745, -0.08409423,  0.6290082 ]],
#        dtype=float32),
#  array([-6.8682057e-05,  6.6235341e-05,  2.7609203e-05,  2.2736853e-01,
#          3.2863524e-04,  0.0000000e+00,  0.0000000e+00,  1.9927073e-05,
#          1.9119906e-01, -7.7558798e-05], dtype=float32)]

# %% [markdown]
# and the output layer:

# %%
print(network1._layers[2].get_weights())
# Out:
# [array([[-0.31280166],
#        [-0.49399233],
#        [-0.54214036],
#        [ 0.43829542],
#        [-0.48061723],
#        [-0.12706345],
#        [ 0.51259404],
#        [-0.6499586 ],
#        [ 0.30410767],
#        [-0.72250193]], dtype=float32), array([0.6071019], dtype=float32)]

# %% [markdown]
# We can also use the network for prediction:

# %%
print(X_xor)
print(network1.predict(X_xor))
# Out:
# [[0. 0.]
#  [1. 0.]
#  [0. 1.]
#  [1. 1.]]
# [[0.764683  ]
#  [0.13425118]
#  [0.13639206]
#  [0.8934836 ]]

# %% [markdown]
# Remember that the network is trying to approximate the values [1, 0, 0, 1].  Let's look at the history of the loss and accuracy over the epochs of training the network using the ```history``` of the trained network:

# %%
plt.plot(history1.history['accuracy'], label='Accuracy')
plt.plot(history1.history['mse'], label='MSE')
plt.ylim([0, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# Let's also look at the decision surface of this network:

# %%
plot_XOR_network(network1)

# %% [markdown]
# We can also add more layers and have more nodes in each layer:

# %%
network2 = keras.Sequential()
network2.add(keras.layers.Dense(50, activation='relu'))
network2.add(keras.layers.Dense(25, activation='relu'))
network2.add(keras.layers.Dense(12, activation='relu'))
network2.add(keras.layers.Dense(1))

loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.SGD(learning_rate=0.005)
network2.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

history2 = network2.fit(X_xor, y_xor, batch_size=2, epochs=512, verbose=0)

# %%
network2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 50)                150
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                312
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 1,750
# Trainable params: 1,750
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model has far more complexity than is necessary for this problem - a total of 1,750 parameters is orders of magnitude larger than necessary, but it still finds a good solution.

# %%
plt.plot(history2.history['accuracy'], label='Accuracy')
plt.plot(history2.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %%
plot_XOR_network(network2)

# %% [markdown]
# ## One hot encoding, Softmax and the Loss Function

# %% [markdown]
# ### One hot encoding
#
# Using The Euclidean distance of the outputs from the true values probably isn't the best loss function to be using: it is designed for regression problems. Instead, we can use the cross entropy loss (yes we are introducing a new term which will be defined shortly).  To do this, one thing we need to do is change our expected outputs from being 0 or 1 to be "one-hot-encoded:"

# %%
y_xor_one_hot = keras.utils.to_categorical(y_xor, 2)

for a,b in zip(y_xor, y_xor_one_hot) :
    print(f'y value {a} maps to the encoding {b}')
# Out:
# y value 1 maps to the encoding [0. 1.]
# y value 0 maps to the encoding [1. 0.]
# y value 0 maps to the encoding [1. 0.]
# y value 1 maps to the encoding [0. 1.]

# %% [markdown]
# In one-hot-encoding, each output is now a vector with zero at each class label that is not correct for the associated input and one at the class label that is correct.  One thing to note with this modification is that our network will now have two outputs.
#
# It's also useful to restrict the outputs of our network to look like probabilities.  One way to do this would be to normalize the outputs to be
# \begin{align*}
# z_1' &= \frac{z_1}{z_1 + z_2} \\
# z_2' &= \frac{z_2}{z_1 + z_2}
# \end{align*}
# which gives us $z_1'$ and $z_2'$ values each between zero and one and summing to one.  One thing to keep in mind here is that although these now form a probability distribution, it isn't necessarily accurate to view $z_1'$ as the "probability that the input is of class one" because the approximation given by our network is just that - an approximation. While useful from a pracitcal standpoint it should not be confused with a rigorously established estimate of the true underlying probability.
#
#
# Another way to do this would be to take the hard max of the outputs,
# \begin{align*}
# z_1' &= \begin{cases} 1 & z_1 \geq z_2 \\ 0 & z_1 < z_2 \end{cases} \\
# z_2' &= \begin{cases} 0 & z_1 \geq z_2 \\ 1 & z_1 < z_2 \end{cases},
# \end{align*}
# which has similar nice properties but is unfortunately not differentiable, so we can't actually use it for classification.
#
# A compromise between these two is softmax.  For our two raw outputs, $z_1$ and $z_2$, the softmax activation function is calculated as
# \begin{align*}
# \text{softmax}(z_1) &= \frac{e^{z_1}}{e^{z_1} + e^{z_2}} \\
# \text{softmax}(z_2) &= \frac{e^{z_2}}{e^{z_1} + e^{z_2}}
# \end{align*}
#
# This is very similar to normalization, but with the exponential function of the raw inputs instead.  This means that values will behave in a manner similar to the softwax while maintaining differentiability.

# %% [markdown]
# ### Visualizing Softmax
#
# Here is a simple bit of code to help you visualize what happens when a set of activations on the last layer of a classification network are run through the softmax function.

# %%
def apply_softmax(acts) :
    exp_acts = np.array([np.exp(x) for x in acts])
    exp_acts_sum = np.sum(exp_acts)
    acts_smax = np.array([np.exp(x)/exp_acts_sum for x in acts])
    return exp_acts, acts_smax

def visualize_softmax(mean, sigma, nsamples, rseed) :
    rng = default_rng(rseed)
    act = rng.normal(mean, sigma, nsamples)
    aex, asf = apply_softmax(act)
    plt.style.use('seaborn-deep')
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(13,5))
    ax1.bar(range(nsamples), act, color='darkred')
    ax1.set_xlabel('Output Node')
    ax1.set_ylabel('Activation')
    ax1.set_title('Input Activations')   
    ax2.bar(range(nsamples), aex, color='darkblue')
    ax2.set_xlabel('Output Node')
    ax2.set_ylabel('After Exponentiation')
    ax2.set_title('Exponentiated Input Activation')  
    ax3.bar(range(nsamples), asf, color='darkgreen')
    ax3.set_xlabel('Output Node')
    ax3.set_ylabel('Activation')
    ax3.set_title('Softmax applied to Activations')
    
    plt.show()

# %%
rseed = np.random.randint(0,99)
visualize_softmax(5, 1.0, 8, rseed)
print(f'Random seed is: {rseed}')
# Out:
# Random seed is: 31

# %% [markdown]
# ### XOR and a One Hot Softmax Output
#
# Our third network still solves XOR but with the one hot encoding and softmax just introduced. Also, the loss function is now Cross Entropy.

# %%
network3 = keras.Sequential()
network3.add(keras.layers.Dense(10, activation='relu'))
network3.add(keras.layers.Dense(2, activation='softmax'))

loss_fn = keras.losses.BinaryCrossentropy()
opt = keras.optimizers.SGD(learning_rate=0.01)
network3.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history3 = network3.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=600, verbose=0)
# Out:
# WARNING:tensorflow:From /Users/ross/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
plt.plot(history3.history['accuracy'], label='Accuracy')
plt.plot(history3.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# To visualize the decision surface, we will plot $z_1 - z_2$.  This is a trick we will use throughout the rest of the notebook.

# %%
plot_XOR_network(network3, two_outputs=True)

# %% [markdown]
# ## Nonconvex Optimization

# %% [markdown]
# For linear models, finding a solution that minimizes some quantity of interest was relatively easy because the error surface has a single global minimum.  Whenever the error function satisfies a certain condition known as "convexity", this is guaranteed to be the case.
# Here's an example of a loss surface of a convex problem:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2)
points = np.r_[True, y[1:] <= y[:-1]] & np.r_[y[:-1] <= y[1:], True]
plt.plot(x, y, label='Loss Surface')
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.title("Convex Optimization")
plt.xticks([])
plt.yticks([])
plt.scatter(x[points], y[points], c='r', label='minimum')
plt.legend();

# %% [markdown]
# As we change the weights of the model, we move around on the blue curve.  The goal is to find a configuration of weights that places us at the location of the red dot, which is the minimum of this function.

# %% [markdown]
# However, due to the nonlinearity of neural networks, there may be more than one minimum.  For example:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2) + 5*np.sin(np.pi*x)
points = np.r_[True, y[1:] < y[:-1]] & np.r_[y[:-1] < y[1:], True]
plt.plot(x, y, label="Loss Surface")
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.xticks([])
plt.yticks([])
plt.title("Nonconvex Optimization")
plt.scatter(x[points], y[points], c='r', label='minima')
plt.legend();

# %% [markdown]
# In this case, there is a single global minimum that represents the optimal solution, but there are a number of other *local* minima.
#
# Gradient descent and many of its variants are the most commonly used algorithms for optimizing the weights of neural networks.  Gradient descent can be thought of as behaving like a ball that is placed on the the loss surface - it rolls down hills.  That means that if an initial configuration of a neural network lies somewhere in a valley around one of the local minima, gradient descent will push it towards that local minimum rather than the global minimum.
# However, that may or may not be a problem!  We are interested in solutions that have high prediction accuracy - not necessarily finding the global minimum.

# %% [markdown]
# ## Gradient Descent Modifications and Regularization

# %% [markdown]
# The simple SGD algorithm has a modification that can help with shallow local minima and plateaus in the loss surface - momentum.  Intuitively, this is the same as the idea would be in physics, where the model builds momentum as it travels, and can continue to follow that momentum rather than just going in the direction of most change.  This helps avoid shallow local minima and can prevent the model from slowing down too much on plateaus.

# %%
opt = keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

# %% [markdown]
# We can also add weight decay to our model, where weights are driven towards small values to reduce the likelihood of overfitting and smooth the loss surface:

# %%
# Pointless Comment

reg = keras.regularizers.l2(1e-4)
network4 = keras.Sequential()
network4.add(keras.layers.Dense(10, activation='relu', kernel_regularizer=reg, bias_regularizer=reg))
network4.add(keras.layers.Dense(2, activation='softmax', kernel_regularizer=reg, bias_regularizer=reg))

# %% [markdown]
# The rest of our setup is the same as it has been previously.

# %%
loss_fn = keras.losses.BinaryCrossentropy()

network4.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history4 = network4.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=100, verbose=0)

# %%
plt.plot(history4.history['accuracy'], label='Accuracy')
plt.plot(history4.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# This network trains *much* faster than the previous models.  While testing this notebook, the model frequently achieved zero loss by epoch 50.

# %%
plot_XOR_network(network4, two_outputs=True)

# %% [markdown]
# There are also more complex optimizers, such as the [Adam optimizer](https://arxiv.org/pdf/1412.6980.pdf) designed by Diederik Kingma and Jimmy Ba.  It uses a variety of techniques like adaptive learning rates and momentums to provide competitive performance.  To use it in Keras, call it as

# %%
opt = keras.optimizers.Adam()

# %% [markdown]
# It has default parameters that empirically work well on a wide class of problems.

# %% [markdown]
# ## Complex Problems

# %% [markdown]
# [Neural Networks, Manifolds, and Topology](https://colah.github.io/posts/2014-03-NN-Manifolds-Topology/) by Christopher Olah has animated versions for $\tanh$ networks of some of the investigations and examples shown here.

# %% [markdown]
# Now let's consider a slightly more difficult problem for neural networks:

# %%
r1 = 0.5
r2 = np.sqrt(2*r1**2)
r3 = np.sqrt(r1**2 + r2**2)

fig = plt.figure()
ax = fig.add_subplot(111)

circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# By itself this is a relatively easy problem - if we convert to polar coordinates, we can just threshold based on the radius and have a very simple classifier that achieves 100% accuracy.  However, if we use the raw $x_1$ and $x_2$ inputs to a neural network, that information must be learned by the network.  The network must be able to construct a closed region in the plane, which requires more complexity than was necessary for XOR.
#
# For training a network we need specific inputs, so we will get 500 points from the circle and 500 from the annulus with their associated class labels:

# %%
X_circle = []
y_circle = []
for i in range(500):
    # Circle
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) > r1:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(0)
        
    # Annulus
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) < r2 or np.linalg.norm(vec) > r3:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(1)
    
X_circle = np.array(X_circle)
X_circle = X_circle.astype('float32')
y_circle = np.array(y_circle)
y_circle_one_hot = keras.utils.to_categorical(y_circle, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X_circle[y_circle==0, 0], X_circle[y_circle==0, 1])
ax.scatter(X_circle[y_circle==1, 0], X_circle[y_circle==1, 1], c='r')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# Let's train a simple network on this and keep trying until we make sure we get a better solution than random:

# %%
while True:
    network5 = keras.Sequential()
    network5.add(keras.layers.Dense(2, activation='relu'))
    network5.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network5.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    
    history5 = network5.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    print('Trained one network to {} accuracy'.format(history5.history['accuracy'][-1]))
    if history5.history['accuracy'][-1] > 0.78:
        break
# Out:
# Trained one network to 0.6510000228881836 accuracy
# Trained one network to 0.6150000095367432 accuracy
# Trained one network to 0.8140000104904175 accuracy

# %%
plt.plot(history5.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network5, two_outputs=True)

# %% [markdown]
# This network gets about 80% accuracy, which is somewhat close to the best that can be expected from this architecture.  Let's look at what it actually does to the data.  The first thing it does is apply the weights of the first layer to transform the data:

# %% [markdown]
# Every data point with a horizontal coordinate below zero has its horizontal coordinate taken to zero - effectively shoving all the negative data to zero on that axis.
#
# We can do the same thing with the second node, which is the vertical axis:

# %% [markdown]
# This doesn't look particularly useful, but notice that all of the blue data points are in the lower left corner.  That means that when the decision boundary is drawn on, they can (mostly) be on one side, even if there is significant mixing with the red points.
#
# That decision boundary comes from the hidden to output weights, as that is the linear classifier the network is using.  In the new space created by applying the first layer, the decision boundary is a straight line:

# %% [markdown]
# Now let's train a network that solves this, with three nodes in its hidden layer.  We may have to train it multiple times for it to find a solution with 100% accuracy.

# %%
while True:
    network6 = keras.Sequential()
    network6.add(keras.layers.Dense(3, activation='relu'))
    network6.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network6.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    history6 = network6.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    
    print('Trained one network to {} accuracy'.format(history6.history['accuracy'][-1]))
    if history6.history['accuracy'][-1] >= 0.996:
        break
# Out:
# Trained one network to 0.9980000257492065 accuracy

# %%
plt.plot(history6.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network6, two_outputs=True)

# %% [markdown]
# This should have perfect or near perfect accuracy on the data we are considering - if it is perfect, it likely has a hexagonal shape, and if it is imperfect it has like found a square shape with the corners overlapping the annulus.

# %% [markdown]
# ## Comments
#
# 1. Some of the intuition from these small, two-input networks may not carry over in expected ways to higher dimensional problems.  Unfortunately, building intuition for those more complex problems is typically difficult due to the limited ability to analyze high dimensional networks.  We will discuss more complex problems in our next notebook.
# 2. Until relatively recently, one of the best methods for hyperparameter selection with neural networks was random search.  More sophisticated methods exist now, but without insight into the dataset it can be difficult to determine how to structure network architecture and training process
# 3. Keras used to be independent from the chosen backend, but its creator now works for Google (the makers of TensorFlow), and backends like PyTorch are no longer being updated, so the "recommended" backend is TensorFlow.  Keras is also being more closely tied into TensorFlow.
